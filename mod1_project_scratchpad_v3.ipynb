# %% [markdown]
# ## MOD1_Project_scratchpad_v3

# %%
#import relevant libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder

# %%
#import sales data
sales_data = pd.read_csv('EXTR_RPSale.csv')
# Out:
# /anaconda3/envs/learn-env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#import data on property
res_info = pd.read_csv('EXTR_ResBldg.csv')
# Out:
# /anaconda3/envs/learn-env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### Inspect sales data

# %%
#what does the data contain?
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2033420 entries, 0 to 2033419
# Data columns (total 24 columns):
# ExciseTaxNbr          int64
# Major                 object
# Minor                 object
# DocumentDate          object
# SalePrice             int64
# RecordingNbr          object
# Volume                object
# Page                  object
# PlatNbr               object
# PlatType              object
# PlatLot               object
# PlatBlock             object
# SellerName            object
# BuyerName             object
# PropertyType          int64
# PrincipalUse          int64
# SaleInstrument        int64
# AFForestLand          object
# AFCurrentUseLand      object
# AFNonProfitUse        object
# AFHistoricProperty    object
# SaleReason            int64
# PropertyClass         int64
# SaleWarning           object
# dtypes: int64(7), object(17)
# memory usage: 372.3+ MB

# %%
#data preview
sales_data.head().T
# Out:
#                                                                     0  \
# ExciseTaxNbr                                                  2687551
# Major                                                          138860
# Minor                                                             110
# DocumentDate                                               08/21/2014
# SalePrice                                                      245000
# RecordingNbr                                           20140828001436
# Volume
# Page
# PlatNbr
# PlatType
# PlatLot
# PlatBlock
# SellerName          WENKLE NOEL SMITH -TRUSTEE                    ...
# BuyerName           ALEXANDER APRIL                               ...
# PropertyType                                                        3
# PrincipalUse                                                        6
# SaleInstrument                                                      3
# AFForestLand                                                        N
# AFCurrentUseLand                                                    N
# AFNonProfitUse                                                      N
# AFHistoricProperty                                                  N
# SaleReason                                                          1
# PropertyClass                                                       8
# SaleWarning
#
#                                                                     1  \
# ExciseTaxNbr                                                  1235111
# Major                                                          664885
# Minor                                                              40
# DocumentDate                                               07/09/1991
# SalePrice                                                           0
# RecordingNbr                                           199203161090
# Volume                                                            071
# Page                                                              001
# PlatNbr                                                        664885
# PlatType                                                            C
# PlatLot                                                B102
# PlatBlock
# SellerName          HERRMAN JEFFREY A+PAULINE A                   ...
# BuyerName           HERRMAN PAULINE A TTEE                        ...
# PropertyType                                                        3
# PrincipalUse                                                        0
# SaleInstrument                                                     26
# AFForestLand                                                        N
# AFCurrentUseLand                                                    N
# AFNonProfitUse                                                      N
# AFHistoricProperty                                                  N
# SaleReason                                                         18
# PropertyClass                                                       3
# SaleWarning                                                        11
#
#                                                                     2  \
# ExciseTaxNbr                                                  2704079
# Major                                                          423943
# Minor                                                              50
# DocumentDate                                               10/11/2014
# SalePrice                                                           0
# RecordingNbr                                           20141205000558
# Volume
# Page
# PlatNbr
# PlatType
# PlatLot
# PlatBlock
# SellerName          STEPHENS ANTHONY P                            ...
# BuyerName           STEPHENS ANTHONY P                            ...
# PropertyType                                                        3
# PrincipalUse                                                        6
# SaleInstrument                                                     15
# AFForestLand                                                        N
# AFCurrentUseLand                                                    N
# AFNonProfitUse                                                      N
# AFHistoricProperty                                                  N
# SaleReason                                                         18
# PropertyClass                                                       8
# SaleWarning                                                  18 31 51
#
#                                                                     3  \
# ExciseTaxNbr                                                  2584094
# Major                                                          403700
# Minor                                                             715
# DocumentDate                                               01/04/2013
# SalePrice                                                           0
# RecordingNbr                                           20130110000910
# Volume
# Page
# PlatNbr
# PlatType
# PlatLot
# PlatBlock
# SellerName          PASTORS EDWIN                                 ...
# BuyerName           PASTORS KHRISTINA                             ...
# PropertyType                                                        3
# PrincipalUse                                                        6
# SaleInstrument                                                     15
# AFForestLand                                                        N
# AFCurrentUseLand                                                    N
# AFNonProfitUse                                                      N
# AFHistoricProperty                                                  N
# SaleReason                                                         11
# PropertyClass                                                       8
# SaleWarning                                                  18 31 38
#
#                                                                     4
# ExciseTaxNbr                                                  1056831
# Major                                                          951120
# Minor                                                             900
# DocumentDate                                               04/20/1989
# SalePrice                                                       85000
# RecordingNbr                                           198904260448
# Volume                                                            117
# Page                                                              053
# PlatNbr                                                        951120
# PlatType                                                            P
# PlatLot                                                90
# PlatBlock
# SellerName          STRATHY FLORENCE G                            ...
# BuyerName           PORTER DONALD D+EVELYN V                      ...
# PropertyType                                                        3
# PrincipalUse                                                        0
# SaleInstrument                                                      2
# AFForestLand                                                        N
# AFCurrentUseLand                                                    N
# AFNonProfitUse                                                      N
# AFHistoricProperty                                                  N
# SaleReason                                                          1
# PropertyClass                                                       9
# SaleWarning                                                        49

# %%
#remove columns with too many missing values and will not be relevant in a regression model
#keep 'SaleReason' for reference purposes only
sales_data = sales_data[['Major', 'Minor', 'DocumentDate', 'SalePrice', 'SaleReason']]

# %%
#preview trimmed data
sales_data.head()
# Out:
#     Major Minor DocumentDate  SalePrice  SaleReason
# 0  138860   110   08/21/2014     245000           1
# 1  664885    40   07/09/1991          0          18
# 2  423943    50   10/11/2014          0          18
# 3  403700   715   01/04/2013          0          11
# 4  951120   900   04/20/1989      85000           1

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2033420 entries, 0 to 2033419
# Data columns (total 5 columns):
# Major           object
# Minor           object
# DocumentDate    object
# SalePrice       int64
# SaleReason      int64
# dtypes: int64(2), object(3)
# memory usage: 77.6+ MB

# %%
#go through same process with building info data
res_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512548 entries, 0 to 512547
# Data columns (total 50 columns):
# Major                 512548 non-null int64
# Minor                 512548 non-null int64
# BldgNbr               512548 non-null int64
# NbrLivingUnits        512548 non-null int64
# Address               512548 non-null object
# BuildingNumber        512548 non-null object
# Fraction              512548 non-null object
# DirectionPrefix       511984 non-null object
# StreetName            512548 non-null object
# StreetType            512548 non-null object
# DirectionSuffix       511984 non-null object
# ZipCode               468452 non-null object
# Stories               512548 non-null float64
# BldgGrade             512548 non-null int64
# BldgGradeVar          512548 non-null int64
# SqFt1stFloor          512548 non-null int64
# SqFtHalfFloor         512548 non-null int64
# SqFt2ndFloor          512548 non-null int64
# SqFtUpperFloor        512548 non-null int64
# SqFtUnfinFull         512548 non-null int64
# SqFtUnfinHalf         512548 non-null int64
# SqFtTotLiving         512548 non-null int64
# SqFtTotBasement       512548 non-null int64
# SqFtFinBasement       512548 non-null int64
# FinBasementGrade      512548 non-null int64
# SqFtGarageBasement    512548 non-null int64
# SqFtGarageAttached    512548 non-null int64
# DaylightBasement      512548 non-null object
# SqFtOpenPorch         512548 non-null int64
# SqFtEnclosedPorch     512548 non-null int64
# SqFtDeck              512548 non-null int64
# HeatSystem            512548 non-null int64
# HeatSource            512548 non-null int64
# BrickStone            512548 non-null int64
# ViewUtilization       512548 non-null object
# Bedrooms              512548 non-null int64
# BathHalfCount         512548 non-null int64
# Bath3qtrCount         512548 non-null int64
# BathFullCount         512548 non-null int64
# FpSingleStory         512548 non-null int64
# FpMultiStory          512548 non-null int64
# FpFreestanding        512548 non-null int64
# FpAdditional          512548 non-null int64
# YrBuilt               512548 non-null int64
# YrRenovated           512548 non-null int64
# PcntComplete          512548 non-null int64
# Obsolescence          512548 non-null int64
# PcntNetCondition      512548 non-null int64
# Condition             512548 non-null int64
# AddnlCost             512548 non-null int64
# dtypes: float64(1), int64(39), object(10)
# memory usage: 195.5+ MB

# %%
res_info.head().T
# Out:
#                                             0                            1  \
# Major                                     520                          640
# Minor                                      67                            7
# BldgNbr                                     1                            1
# NbrLivingUnits                              1                            1
# Address              6781   MARS AVE S  98108  45216   196TH AVE SE  98022
# BuildingNumber                          6781                         45216
# Fraction
# DirectionPrefix
# StreetName          MARS                         196TH
# StreetType                             AVE                          AVE
# DirectionSuffix                            S                            SE
# ZipCode                                 98108                        98022
# Stories                                     1                            2
# BldgGrade                                   7                            6
# BldgGradeVar                                0                            0
# SqFt1stFloor                             1440                         1100
# SqFtHalfFloor                               0                            0
# SqFt2ndFloor                                0                          670
# SqFtUpperFloor                              0                            0
# SqFtUnfinFull                               0                            0
# SqFtUnfinHalf                               0                            0
# SqFtTotLiving                            2360                         1770
# SqFtTotBasement                           920                            0
# SqFtFinBasement                           920                            0
# FinBasementGrade                            6                            0
# SqFtGarageBasement                          0                            0
# SqFtGarageAttached                          0                            0
# DaylightBasement                            N
# SqFtOpenPorch                               0                            0
# SqFtEnclosedPorch                           0                            0
# SqFtDeck                                  250                            0
# HeatSystem                                  5                            4
# HeatSource                                  2                            3
# BrickStone                                  0                            0
# ViewUtilization                             N
# Bedrooms                                    3                            3
# BathHalfCount                               0                            1
# Bath3qtrCount                               1                            0
# BathFullCount                               2                            1
# FpSingleStory                               0                            0
# FpMultiStory                                1                            1
# FpFreestanding                              0                            0
# FpAdditional                                1                            0
# YrBuilt                                  1940                         1961
# YrRenovated                              2014                            0
# PcntComplete                                0                            0
# Obsolescence                                0                            0
# PcntNetCondition                            0                            0
# Condition                                   3                            4
# AddnlCost                                   0                            0
#
#                                               2                          3  \
# Major                                       640                        660
# Minor                                        16                         96
# BldgNbr                                       1                          1
# NbrLivingUnits                                1                          1
# Address             20410  SE 456TH WAY   98022   8501  S 259TH ST   98030
# BuildingNumber                            20410                      8501
# Fraction
# DirectionPrefix                              SE                         S
# StreetName            456TH                      259TH
# StreetType                               WAY                        ST
# DirectionSuffix
# ZipCode                                   98022                      98030
# Stories                                       2                        1.5
# BldgGrade                                     9                          7
# BldgGradeVar                                  0                          0
# SqFt1stFloor                               1780                        950
# SqFtHalfFloor                                 0                        410
# SqFt2ndFloor                                940                          0
# SqFtUpperFloor                                0                          0
# SqFtUnfinFull                                 0                          0
# SqFtUnfinHalf                                 0                          0
# SqFtTotLiving                              2720                       1360
# SqFtTotBasement                               0                        950
# SqFtFinBasement                               0                          0
# FinBasementGrade                              0                          0
# SqFtGarageBasement                            0                          0
# SqFtGarageAttached                          740                          0
# DaylightBasement                                                         N
# SqFtOpenPorch                                70                          0
# SqFtEnclosedPorch                             0                          0
# SqFtDeck                                      0                          0
# HeatSystem                                    7                          5
# HeatSource                                    3                          1
# BrickStone                                    0                          0
# ViewUtilization                                                          N
# Bedrooms                                      3                          4
# BathHalfCount                                 1                          0
# Bath3qtrCount                                 0                          0
# BathFullCount                                 3                          1
# FpSingleStory                                 1                          0
# FpMultiStory                                  0                          0
# FpFreestanding                                0                          0
# FpAdditional                                  0                          0
# YrBuilt                                    2004                       1933
# YrRenovated                                   0                          0
# PcntComplete                                  0                          0
# Obsolescence                                  0                          0
# PcntNetCondition                              0                          0
# Condition                                     3                          4
# AddnlCost                                     0                          0
#
#                                             4
# Major                                     720
# Minor                                      13
# BldgNbr                                     1
# NbrLivingUnits                              1
# Address               84   LOGAN AVE S  98055
# BuildingNumber                          84
# Fraction
# DirectionPrefix
# StreetName          LOGAN
# StreetType                             AVE
# DirectionSuffix                            S
# ZipCode                                 98055
# Stories                                   1.5
# BldgGrade                                   6
# BldgGradeVar                                0
# SqFt1stFloor                              920
# SqFtHalfFloor                             350
# SqFt2ndFloor                                0
# SqFtUpperFloor                              0
# SqFtUnfinFull                               0
# SqFtUnfinHalf                               0
# SqFtTotLiving                            1270
# SqFtTotBasement                           420
# SqFtFinBasement                             0
# FinBasementGrade                            0
# SqFtGarageBasement                          0
# SqFtGarageAttached                          0
# DaylightBasement                            N
# SqFtOpenPorch                             130
# SqFtEnclosedPorch                           0
# SqFtDeck                                    0
# HeatSystem                                  5
# HeatSource                                  2
# BrickStone                                  0
# ViewUtilization                             N
# Bedrooms                                    3
# BathHalfCount                               0
# Bath3qtrCount                               0
# BathFullCount                               1
# FpSingleStory                               1
# FpMultiStory                                0
# FpFreestanding                              0
# FpAdditional                                0
# YrBuilt                                  1924
# YrRenovated                                 0
# PcntComplete                                0
# Obsolescence                                0
# PcntNetCondition                            0
# Condition                                   3
# AddnlCost                                   0

# %%
#res_info.describe().T

# %%
#remove columns with too many missing values and will not be relevant in a regression model
#first pass
res_info = res_info[['Major', 'Minor', 'NbrLivingUnits', 'ZipCode', 'BldgGrade', 
                       'Stories','SqFt1stFloor','SqFtHalfFloor','SqFt2ndFloor',
                     'SqFtUpperFloor','SqFtTotLiving', 'SqFtTotBasement',
                     'Bedrooms', 'BathHalfCount', 'Bath3qtrCount','BathFullCount',
                     'YrBuilt', 'YrRenovated', 'Condition']]

# %%
#consolidate squarefeet columns into area above ground and add total bathroom counts
res_info['BathCountSum'] = (res_info.BathFullCount + res_info.BathHalfCount*0.5 + 
                             res_info.Bath3qtrCount*0.75)
res_info['SqFtAboveGround'] = (res_info.SqFt1stFloor + res_info.SqFt2ndFloor + 
                               res_info.SqFtHalfFloor + res_info.SqFtUpperFloor)

# %%
#drop columns
res_info = res_info.drop(['SqFt1stFloor', 'SqFtHalfFloor', 'SqFt2ndFloor','SqFtUpperFloor',
                         'BathFullCount', 'BathHalfCount', 'Bath3qtrCount'], axis=1)

# %%
#preview consolidated data
res_info.head().T
# Out:
#                      0      1      2      3      4
# Major              520    640    640    660    720
# Minor               67      7     16     96     13
# NbrLivingUnits       1      1      1      1      1
# ZipCode          98108  98022  98022  98030  98055
# BldgGrade            7      6      9      7      6
# Stories              1      2      2    1.5    1.5
# SqFtTotLiving     2360   1770   2720   1360   1270
# SqFtTotBasement    920      0      0    950    420
# Bedrooms             3      3      3      4      3
# YrBuilt           1940   1961   2004   1933   1924
# YrRenovated       2014      0      0      0      0
# Condition            3      4      3      4      3
# BathCountSum      2.75    1.5    3.5      1      1
# SqFtAboveGround   1440   1770   2720   1360   1270

# %%
#merge two data sets into one using inner join with major and minor columns
#need to cast Major and Minor Columns into numbers before merging
sales_data['Major'] = pd.to_numeric(sales_data['Major'], errors='coerce')
sales_data['Minor'] = pd.to_numeric(sales_data['Minor'], errors='coerce')

# %%
#merge two data sets
kc_data = pd.merge(sales_data, res_info, on=['Major', 'Minor'])

# %%
#preview merged data
kc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1451791 entries, 0 to 1451790
# Data columns (total 17 columns):
# Major              1451791 non-null float64
# Minor              1451791 non-null float64
# DocumentDate       1451791 non-null object
# SalePrice          1451791 non-null int64
# SaleReason         1451791 non-null int64
# NbrLivingUnits     1451791 non-null int64
# ZipCode            1333409 non-null object
# BldgGrade          1451791 non-null int64
# Stories            1451791 non-null float64
# SqFtTotLiving      1451791 non-null int64
# SqFtTotBasement    1451791 non-null int64
# Bedrooms           1451791 non-null int64
# YrBuilt            1451791 non-null int64
# YrRenovated        1451791 non-null int64
# Condition          1451791 non-null int64
# BathCountSum       1451791 non-null float64
# SqFtAboveGround    1451791 non-null int64
# dtypes: float64(4), int64(11), object(2)
# memory usage: 199.4+ MB

# %%
kc_data.head().T
# Out:
#                           0           1           2           3           4
# Major                138860      138860      138860      138860      423943
# Minor                   110         110         110         110          50
# DocumentDate     08/21/2014  06/12/1989  01/16/2005  06/08/2005  10/11/2014
# SalePrice            245000      109300       14684           0           0
# SaleReason                1           1          14           5          18
# NbrLivingUnits            1           1           1           1           1
# ZipCode               98002       98002       98002       98002       98092
# BldgGrade                 7           7           7           7           6
# Stories                   1           1           1           1           1
# SqFtTotLiving          1490        1490        1490        1490         960
# SqFtTotBasement           0           0           0           0           0
# Bedrooms                  3           3           3           3           3
# YrBuilt                1989        1989        1989        1989        1969
# YrRenovated               0           0           0           0           0
# Condition                 3           3           3           3           4
# BathCountSum              2           2           2           2           1
# SqFtAboveGround        1490        1490        1490        1490         960

# %% [markdown]
# ### clean data based on assumption and availability

# %%
#convert date to timestamp to better utilize data (long wait time expected)
kc_data['Date'] = kc_data['DocumentDate'].apply(pd.Timestamp)

# %%
kc_data['Year'] = kc_data['Date'].apply(lambda ts: ts.year)

# %%
kc_data = kc_data.drop(['DocumentDate'], axis=1)

# %%
#look at housing prices vs year
year_groupby = kc_data.groupby('Year')
year_groupby.describe()['SalePrice']
# Out:
#         count           mean           std       min       25%       50%  \
# Year
# 1900      1.0       0.000000           NaN       0.0       0.0       0.0
# 1934      1.0  125000.000000           NaN  125000.0  125000.0  125000.0
# 1951      1.0       0.000000           NaN       0.0       0.0       0.0
# 1953      1.0       0.000000           NaN       0.0       0.0       0.0
# 1954      2.0     300.000000  4.242641e+02       0.0     150.0     300.0
# 1955      3.0    3166.666667  5.484828e+03       0.0       0.0       0.0
# 1957      1.0       0.000000           NaN       0.0       0.0       0.0
# 1958      1.0       0.000000           NaN       0.0       0.0       0.0
# 1959      2.0    6125.000000  8.662058e+03       0.0    3062.5    6125.0
# 1960      4.0     575.000000  1.150000e+03       0.0       0.0       0.0
# 1961      5.0    2163.000000  4.836615e+03       0.0       0.0       0.0
# 1962      5.0    5669.200000  5.361944e+03       0.0       0.0    7200.0
# 1963      7.0    2357.142857  6.236414e+03       0.0       0.0       0.0
# 1964     18.0    4572.222222  7.539196e+03       0.0       0.0       0.0
# 1965      8.0    8064.750000  7.439983e+03       0.0       0.0    9325.0
# 1966     10.0    9500.000000  1.015983e+04       0.0       0.0    7500.0
# 1967     31.0    2104.838710  5.589430e+03       0.0       0.0       0.0
# 1968      7.0    8357.142857  1.094195e+04       0.0       0.0       0.0
# 1969      8.0    2356.250000  4.503287e+03       0.0       0.0       0.0
# 1970     13.0    6807.692308  1.350430e+04       0.0       0.0       0.0
# 1971     13.0    4396.153846  7.118768e+03       0.0       0.0       0.0
# 1972     20.0    2075.000000  5.842843e+03       0.0       0.0       0.0
# 1973     28.0    3196.428571  1.335993e+04       0.0       0.0       0.0
# 1974     25.0    2940.160000  7.328200e+03       0.0       0.0       0.0
# 1975     30.0    5445.833333  1.296276e+04       0.0       0.0       0.0
# 1976     44.0    3285.340909  1.094160e+04       0.0       0.0       0.0
# 1977     64.0    2305.156250  6.899942e+03       0.0       0.0       0.0
# 1978     59.0   15167.542373  6.295382e+04       0.0       0.0       0.0
# 1979     66.0    4968.181818  1.770805e+04       0.0       0.0       0.0
# 1980    132.0     911.537879  4.794083e+03       0.0       0.0       0.0
# ...       ...            ...           ...       ...       ...       ...
# 1991  13324.0  122338.432603  1.463807e+05       0.0       0.0  117500.0
# 1992  50695.0  120066.307466  2.859067e+05       0.0       0.0  100000.0
# 1993  50742.0  109286.650250  1.629784e+05       0.0       0.0   97350.0
# 1994  46394.0  154579.740096  4.900912e+05       0.0       0.0  119950.0
# 1995  40219.0  131795.011164  1.722073e+05       0.0       0.0  123000.0
# 1996  44529.0  153471.210919  2.923894e+05       0.0       0.0  130000.0
# 1997  50388.0  191829.559359  4.801014e+05       0.0       0.0  141000.0
# 1998  55524.0  180154.001009  3.022562e+05       0.0       0.0  149500.0
# 1999  52642.0  216681.138084  3.749706e+05       0.0       0.0  169000.0
# 2000  48888.0  269411.112154  5.786929e+05       0.0       0.0  185000.0
# 2001  52046.0  306921.880298  8.622779e+05       0.0       0.0  180000.0
# 2002  57088.0  331854.050046  1.042429e+06       0.0       0.0  189000.0
# 2003  64251.0  364122.320213  1.466624e+06       0.0       0.0  211500.0
# 2004  64511.0  437120.984406  1.367069e+06       0.0       0.0  250000.0
# 2005  65628.0  498371.682879  1.623171e+06       0.0       0.0  289000.0
# 2006  58181.0  461542.525567  1.292049e+06       0.0       0.0  321950.0
# 2007  48284.0  422005.115628  7.535236e+05       0.0       0.0  330000.0
# 2008  35621.0  377506.095505  9.564663e+05       0.0       0.0  250000.0
# 2009  38092.0  252144.954452  5.555903e+05       0.0       0.0   55000.0
# 2010  39582.0  366256.768556  1.432754e+06       0.0       0.0  140000.0
# 2011  40704.0  362207.758500  1.067450e+06       0.0       0.0  135410.5
# 2012  44577.0  345162.616417  8.928626e+05       0.0       0.0  215000.0
# 2013  49202.0  408891.334072  1.231654e+06       0.0       0.0  270000.0
# 2014  45368.0  395088.370680  7.004757e+05       0.0       0.0  305000.0
# 2015  49382.0  434380.331983  8.924355e+05       0.0       0.0  335000.0
# 2016  50285.0  455116.436134  5.631924e+05       0.0       0.0  375000.0
# 2017  48969.0  527484.307725  7.043202e+05    -600.0       0.0  436385.0
# 2018  43352.0  561898.732907  7.326412e+05    -400.0       0.0  462600.0
# 2019  19906.0  567769.008339  7.678236e+05       0.0       0.0  499000.0
# 2021      1.0  795000.000000           NaN  795000.0  795000.0  795000.0
#
#             75%          max
# Year
# 1900       0.00          0.0
# 1934  125000.00     125000.0
# 1951       0.00          0.0
# 1953       0.00          0.0
# 1954     450.00        600.0
# 1955    4750.00       9500.0
# 1957       0.00          0.0
# 1958       0.00          0.0
# 1959    9187.50      12250.0
# 1960     575.00       2300.0
# 1961       0.00      10815.0
# 1962   10196.00      10950.0
# 1963       0.00      16500.0
# 1964    9962.50      22000.0
# 1965   13967.00      16500.0
# 1966   18875.00      21500.0
# 1967       0.00      19000.0
# 1968   16250.00      26000.0
# 1969    1887.50      12000.0
# 1970    8000.00      45750.0
# 1971    8750.00      16800.0
# 1972       0.00      19500.0
# 1973       0.00      70000.0
# 1974       0.00      28004.0
# 1975    1700.00      64000.0
# 1976       0.00      60000.0
# 1977       0.00      32500.0
# 1978       0.00     450935.0
# 1979       0.00     126500.0
# 1980       0.00      40998.0
# ...         ...          ...
# 1991  170287.50    4300000.0
# 1992  160000.00   10731144.0
# 1993  161000.00    8000000.0
# 1994  179000.00   10149957.0
# 1995  182500.00   10072262.0
# 1996  195000.00    5900000.0
# 1997  219500.00    8200056.0
# 1998  236000.00   12000000.0
# 1999  267000.00   12999999.0
# 2000  294950.00   20000000.0
# 2001  295819.75   10699582.0
# 2002  315000.00   17467200.0
# 2003  339000.00  175374063.0
# 2004  385000.00   15951426.0
# 2005  442500.00   21840000.0
# 2006  495000.00   19560000.0
# 2007  529600.00   14000000.0
# 2008  455000.00   15800000.0
# 2009  378500.00   27920653.0
# 2010  400000.00   29102600.0
# 2011  382000.00   15250000.0
# 2012  420000.00   21625000.0
# 2013  480156.25   24500000.0
# 2014  528000.00   16000000.0
# 2015  575000.00   30000000.0
# 2016  643000.00   13450000.0
# 2017  740000.00   23375000.0
# 2018  790000.00   26797000.0
# 2019  785000.00   37500000.0
# 2021  795000.00     795000.0
#
# [70 rows x 8 columns]

# %%
#remove years with low data and outlier year 2021, keep year range between 1982-2019
kc_data = kc_data.loc[kc_data['Year']>1981]
kc_data = kc_data.loc[kc_data['Year']<2020]

# %%
kc_data.shape
# Out:
# (1450912, 18)

# %%
#visualize price changes over the years with boxplot (excluding outliers)
#kc_data.boxplot(column='SalePrice', by='Year', figsize=(12,6), showfliers=True)

# %%
#significant outliers exists, on both ends, requires removal, remove 0s and extreme high values
kc_data = kc_data.loc[kc_data['SalePrice']>0]
kc_data = kc_data.loc[kc_data['SalePrice']<5000000]

# %%
kc_data.boxplot(column='SalePrice', by='Year', figsize=(12,6), showfliers=True)

# %%
#remove sale prices higher than 1,000,000 to accommodate for non-luxury home buyers
kc_data = kc_data.loc[kc_data['SalePrice']<1000000]

# %%
kc_data.boxplot(column='SalePrice', by='Year', figsize=(12,6), showfliers=True)

# %%
#remove low sale prices, census data
kc_data = kc_data.loc[kc_data['SalePrice']>20000]

# %%
#remove properties with building grade codes 1-4, which does not meet code
#reference https://info.kingcounty.gov/assessor/esales/Glossary.aspx?type=r
kc_data = kc_data.loc[kc_data['BldgGrade']>4]
kc_data = kc_data.loc[kc_data['BldgGrade']<20]

# %%
kc_data.BldgGrade.value_counts()
# Out:
# 7     375143
# 8     250266
# 9     104275
# 6      89690
# 10     40994
# 5      11871
# 11     11506
# 12      2385
# 13       277
# Name: BldgGrade, dtype: int64

# %%
kc_data.describe()
# Out:
#                Major          Minor      SalePrice     SaleReason  \
# count  886407.000000  886407.000000  886407.000000  886407.000000
# mean   452949.431231    1489.525188  328401.729392       1.989109
# std    287171.637374    2760.766323  209498.569707       3.406609
# min        40.000000       1.000000   20011.000000       0.000000
# 25%    206190.000000     118.000000  167200.000000       1.000000
# 50%    387682.000000     325.000000  278000.000000       1.000000
# 75%    727810.000000     970.000000  438000.000000       1.000000
# max    990600.000000    9692.000000  999999.000000      19.000000
#
#        NbrLivingUnits      BldgGrade        Stories  SqFtTotLiving  \
# count   886407.000000  886407.000000  886407.000000  886407.000000
# mean         1.018899       7.595637       1.479460    2069.894324
# std          0.159772       1.120397       0.508361     880.265965
# min          1.000000       5.000000       1.000000       0.000000
# 25%          1.000000       7.000000       1.000000    1440.000000
# 50%          1.000000       7.000000       1.500000    1930.000000
# 75%          1.000000       8.000000       2.000000    2540.000000
# max         11.000000      13.000000       4.000000   21650.000000
#
#        SqFtTotBasement       Bedrooms        YrBuilt    YrRenovated  \
# count    886407.000000  886407.000000  886407.000000  886407.000000
# mean        461.911087       3.380518    1971.690008      91.371704
# std         569.251544       0.925994      29.141653     417.302929
# min           0.000000       0.000000    1894.000000       0.000000
# 25%           0.000000       3.000000    1952.000000       0.000000
# 50%           0.000000       3.000000    1977.000000       0.000000
# 75%         940.000000       4.000000    1996.000000       0.000000
# max       10490.000000      37.000000    2019.000000    2019.000000
#
#            Condition   BathCountSum  SqFtAboveGround           Year
# count  886407.000000  886407.000000    886407.000000  886407.000000
# mean        3.426338       2.130242      1788.017574    2003.296318
# std         0.645791       0.763150       811.351689       8.806075
# min         1.000000       0.000000         0.000000    1982.000000
# 25%         3.000000       1.750000      1200.000000    1997.000000
# 50%         3.000000       2.250000      1575.000000    2003.000000
# 75%         4.000000       2.500000      2230.000000    2011.000000
# max         5.000000      34.000000     20560.000000    2019.000000

# %%
#remove SqFtTot less than 500,
kc_data = kc_data.loc[kc_data['SqFtTotLiving']>500]

# %%
#remove SqFtTot more than than 5000
kc_data = kc_data.loc[kc_data['SqFtTotLiving']<5001]

# %%
kc_data.describe().T
# Out:
#                     count           mean            std      min        25%  \
# Major            877900.0  453561.033021  287214.175258     40.0  207850.00
# Minor            877900.0    1474.632382    2742.291339      1.0     117.00
# SalePrice        877900.0  327392.393104  208521.483851  20011.0  167000.00
# SaleReason       877900.0       1.986833       3.403818      0.0       1.00
# NbrLivingUnits   877900.0       1.018819       0.156276      1.0       1.00
# BldgGrade        877900.0       7.576841       1.084390      5.0       7.00
# Stories          877900.0       1.477005       0.507588      1.0       1.00
# SqFtTotLiving    877900.0    2045.046512     807.691763    504.0    1440.00
# SqFtTotBasement  877900.0     455.768714     556.752533      0.0       0.00
# Bedrooms         877900.0       3.375905       0.900604      0.0       3.00
# YrBuilt          877900.0    1971.541589      29.091687   1894.0    1952.00
# YrRenovated      877900.0      90.573282     415.550850      0.0       0.00
# Condition        877900.0       3.428494       0.646487      1.0       3.00
# BathCountSum     877900.0       2.116558       0.727288      0.0       1.75
# SqFtAboveGround  877900.0    1768.871402     760.752887    200.0    1200.00
# Year             877900.0    2003.316061       8.809017   1982.0    1997.00
#
#                        50%       75%        max
# Major            388580.00  728390.0  990600.00
# Minor               321.00     961.0    9692.00
# SalePrice        277200.00  435000.0  999999.00
# SaleReason            1.00       1.0      19.00
# NbrLivingUnits        1.00       1.0       4.00
# BldgGrade             7.00       8.0      13.00
# Stories               1.50       2.0       4.00
# SqFtTotLiving      1920.00    2520.0    5000.00
# SqFtTotBasement       0.00     940.0    6564.00
# Bedrooms              3.00       4.0      33.00
# YrBuilt            1977.00    1995.0    2019.00
# YrRenovated           0.00       0.0    2019.00
# Condition             3.00       4.0       5.00
# BathCountSum          2.25       2.5      18.25
# SqFtAboveGround    1570.00    2220.0    9280.00
# Year               2003.00    2011.0    2019.00

# %%
#remove values bathrooms value less than 0.5, unlikely to be a house or outlier
kc_data = kc_data.loc[kc_data['BathCountSum'] > 0.5]

# %%
#remove values bathrooms value more than 5 as outlier
kc_data = kc_data.loc[kc_data['BathCountSum'] <= 5]

# %%
kc_data.shape
# Out:
# (876777, 18)

# %%
#remove bedroom values less than 1, unlikely to be house
kc_data = kc_data.loc[kc_data['Bedrooms'] >= 1]

# %%
#remove bedroom values more than 10 as outliers
kc_data = kc_data.loc[kc_data['Bedrooms'] < 11]

# %%
kc_data.shape
# Out:
# (876326, 18)

# %%
kc_data.describe().T
# Out:
#                     count           mean            std       min        25%  \
# Major            876326.0  453673.746142  287225.660947     40.00  208520.00
# Minor            876326.0    1472.861951    2740.192473      1.00     117.00
# SalePrice        876326.0  327324.645228  208433.489618  20011.00  167000.00
# SaleReason       876326.0       1.986186       3.402492      0.00       1.00
# NbrLivingUnits   876326.0       1.018445       0.154107      1.00       1.00
# BldgGrade        876326.0       7.576279       1.083036      5.00       7.00
# Stories          876326.0       1.476578       0.507365      1.00       1.00
# SqFtTotLiving    876326.0    2043.792703     805.459661    504.00    1440.00
# SqFtTotBasement  876326.0     455.725666     556.452378      0.00       0.00
# Bedrooms         876326.0       3.376386       0.887721      1.00       3.00
# YrBuilt          876326.0    1971.520370      29.082270   1894.00    1952.00
# YrRenovated      876326.0      90.375262     415.116366      0.00       0.00
# Condition        876326.0       3.428997       0.646614      1.00       3.00
# BathCountSum     876326.0       2.115061       0.718554      0.75       1.75
# SqFtAboveGround  876326.0    1767.617394     758.737029    200.00    1200.00
# Year             876326.0    2003.315777       8.809063   1982.00    1997.00
#
#                        50%       75%       max
# Major            388580.00  728390.0  990600.0
# Minor               321.00     960.0    9692.0
# SalePrice        277000.00  435000.0  999999.0
# SaleReason            1.00       1.0      19.0
# NbrLivingUnits        1.00       1.0       4.0
# BldgGrade             7.00       8.0      13.0
# Stories               1.50       2.0       4.0
# SqFtTotLiving      1920.00    2520.0    5000.0
# SqFtTotBasement       0.00     940.0    6564.0
# Bedrooms              3.00       4.0      10.0
# YrBuilt            1977.00    1995.0    2019.0
# YrRenovated           0.00       0.0    2019.0
# Condition             3.00       4.0       5.0
# BathCountSum          2.25       2.5       5.0
# SqFtAboveGround    1570.00    2210.0    5680.0
# Year               2003.00    2011.0    2019.0

# %%
#basement values mostly 0, remove column
kc_data = kc_data.drop(['SqFtTotBasement'], axis=1)

# %%
kc_data.describe().T
# Out:
#                     count           mean            std       min        25%  \
# Major            876326.0  453673.746142  287225.660947     40.00  208520.00
# Minor            876326.0    1472.861951    2740.192473      1.00     117.00
# SalePrice        876326.0  327324.645228  208433.489618  20011.00  167000.00
# SaleReason       876326.0       1.986186       3.402492      0.00       1.00
# NbrLivingUnits   876326.0       1.018445       0.154107      1.00       1.00
# BldgGrade        876326.0       7.576279       1.083036      5.00       7.00
# Stories          876326.0       1.476578       0.507365      1.00       1.00
# SqFtTotLiving    876326.0    2043.792703     805.459661    504.00    1440.00
# Bedrooms         876326.0       3.376386       0.887721      1.00       3.00
# YrBuilt          876326.0    1971.520370      29.082270   1894.00    1952.00
# YrRenovated      876326.0      90.375262     415.116366      0.00       0.00
# Condition        876326.0       3.428997       0.646614      1.00       3.00
# BathCountSum     876326.0       2.115061       0.718554      0.75       1.75
# SqFtAboveGround  876326.0    1767.617394     758.737029    200.00    1200.00
# Year             876326.0    2003.315777       8.809063   1982.00    1997.00
#
#                        50%       75%       max
# Major            388580.00  728390.0  990600.0
# Minor               321.00     960.0    9692.0
# SalePrice        277000.00  435000.0  999999.0
# SaleReason            1.00       1.0      19.0
# NbrLivingUnits        1.00       1.0       4.0
# BldgGrade             7.00       8.0      13.0
# Stories               1.50       2.0       4.0
# SqFtTotLiving      1920.00    2520.0    5000.0
# Bedrooms              3.00       4.0      10.0
# YrBuilt            1977.00    1995.0    2019.0
# YrRenovated           0.00       0.0    2019.0
# Condition             3.00       4.0       5.0
# BathCountSum          2.25       2.5       5.0
# SqFtAboveGround    1570.00    2210.0    5680.0
# Year               2003.00    2011.0    2019.0

# %%
#backup data
kc_data_backup = kc_data.copy()

# %%
kc_data['Renovation'] = kc_data['YrRenovated'].apply(lambda x: 1 if x > 0 else 0)

# %%
#calculate effective age based on year built or renovations
kc_data['PptyAge'] = ((2019-kc_data.YrRenovated)*((kc_data.Renovation+1)//2) + 
                      (2019-kc_data.YrBuilt)*((kc_data.Renovation+1)%2))

# %%
kc_data.describe().T
# Out:
#                     count           mean            std       min        25%  \
# Major            876326.0  453673.746142  287225.660947     40.00  208520.00
# Minor            876326.0    1472.861951    2740.192473      1.00     117.00
# SalePrice        876326.0  327324.645228  208433.489618  20011.00  167000.00
# SaleReason       876326.0       1.986186       3.402492      0.00       1.00
# NbrLivingUnits   876326.0       1.018445       0.154107      1.00       1.00
# BldgGrade        876326.0       7.576279       1.083036      5.00       7.00
# Stories          876326.0       1.476578       0.507365      1.00       1.00
# SqFtTotLiving    876326.0    2043.792703     805.459661    504.00    1440.00
# Bedrooms         876326.0       3.376386       0.887721      1.00       3.00
# YrBuilt          876326.0    1971.520370      29.082270   1894.00    1952.00
# YrRenovated      876326.0      90.375262     415.116366      0.00       0.00
# Condition        876326.0       3.428997       0.646614      1.00       3.00
# BathCountSum     876326.0       2.115061       0.718554      0.75       1.75
# SqFtAboveGround  876326.0    1767.617394     758.737029    200.00    1200.00
# Year             876326.0    2003.315777       8.809063   1982.00    1997.00
# Renovation       876326.0       0.045256       0.207865      0.00       0.00
# PptyAge          876326.0      44.871363      28.462120      0.00      22.00
#
#                        50%       75%       max
# Major            388580.00  728390.0  990600.0
# Minor               321.00     960.0    9692.0
# SalePrice        277000.00  435000.0  999999.0
# SaleReason            1.00       1.0      19.0
# NbrLivingUnits        1.00       1.0       4.0
# BldgGrade             7.00       8.0      13.0
# Stories               1.50       2.0       4.0
# SqFtTotLiving      1920.00    2520.0    5000.0
# Bedrooms              3.00       4.0      10.0
# YrBuilt            1977.00    1995.0    2019.0
# YrRenovated           0.00       0.0    2019.0
# Condition             3.00       4.0       5.0
# BathCountSum          2.25       2.5       5.0
# SqFtAboveGround    1570.00    2210.0    5680.0
# Year               2003.00    2011.0    2019.0
# Renovation            0.00       0.0       1.0
# PptyAge              40.00      64.0     125.0

# %%
#backup data//
kc_data_backup = kc_data.copy()

# %%
#eliminate columns not intended to be used as features
kc_data = kc_data[['SalePrice', 'NbrLivingUnits', 'BldgGrade', 'Stories', 'SqFtTotLiving', 
                   'Bedrooms', 'BathCountSum','Condition', 'Renovation','PptyAge']]

# %%
kc_data.head().T
# Out:
#                       0         1        6         7          11
# SalePrice       245000.0  109300.0  96000.0  127500.0  464500.00
# NbrLivingUnits       1.0       1.0      1.0       1.0       1.00
# BldgGrade            7.0       7.0      6.0       6.0       7.00
# Stories              1.0       1.0      1.0       1.0       1.00
# SqFtTotLiving     1490.0    1490.0    960.0     960.0    1780.00
# Bedrooms             3.0       3.0      3.0       3.0       4.00
# BathCountSum         2.0       2.0      1.0       1.0       1.75
# Condition            3.0       3.0      4.0       4.0       5.00
# Renovation           0.0       0.0      0.0       0.0       0.00
# PptyAge             30.0      30.0     50.0      50.0      62.00

# %%
#split into training and test sets
kc_train, kc_test = train_test_split(kc_data, test_size=0.3)

# %%
kc_train.describe().T
# Out:
#                    count           mean            std       min        25%  \
# SalePrice       613428.0  327322.464239  208601.410951  20011.00  167000.00
# NbrLivingUnits  613428.0       1.018380       0.153712      1.00       1.00
# BldgGrade       613428.0       7.576446       1.082913      5.00       7.00
# Stories         613428.0       1.476480       0.507316      1.00       1.00
# SqFtTotLiving   613428.0    2043.561543     805.420802    504.00    1440.00
# Bedrooms        613428.0       3.376101       0.887480      1.00       3.00
# BathCountSum    613428.0       2.114881       0.718606      0.75       1.75
# Condition       613428.0       3.428138       0.646434      1.00       3.00
# Renovation      613428.0       0.045404       0.208188      0.00       0.00
# PptyAge         613428.0      44.849534      28.460523      0.00      22.00
#
#                       50%       75%       max
# SalePrice       277000.00  435000.0  999999.0
# NbrLivingUnits       1.00       1.0       4.0
# BldgGrade            7.00       8.0      13.0
# Stories              1.50       2.0       4.0
# SqFtTotLiving     1920.00    2520.0    5000.0
# Bedrooms             3.00       4.0      10.0
# BathCountSum         2.25       2.5       5.0
# Condition            3.00       4.0       5.0
# Renovation           0.00       0.0       1.0
# PptyAge             40.00      64.0     119.0

# %%
kc_train['SalePrice'].plot('hist', bins=20)

# %%
#pd.plotting.scatter_matrix(kc_train, figsize  = [12, 12]);

# %%
#view correlation for training data
kc_train.corr()
# Out:
#                 SalePrice  NbrLivingUnits  BldgGrade   Stories  SqFtTotLiving  \
# SalePrice        1.000000       -0.001465   0.424786  0.276885       0.389360
# NbrLivingUnits  -0.001465        1.000000  -0.056571  0.000014       0.043616
# BldgGrade        0.424786       -0.056571   1.000000  0.482228       0.729478
# Stories          0.276885        0.000014   0.482228  1.000000       0.418047
# SqFtTotLiving    0.389360        0.043616   0.729478  0.418047       1.000000
# Bedrooms         0.188493        0.142438   0.346334  0.218944       0.598069
# BathCountSum     0.331919        0.087586   0.616993  0.506066       0.736130
# Condition       -0.009167       -0.019790  -0.171071 -0.270637      -0.088891
# Renovation       0.024597        0.020533  -0.011961  0.005820       0.050420
# PptyAge         -0.185668        0.098408  -0.472223 -0.479102      -0.378693
#
#                 Bedrooms  BathCountSum  Condition  Renovation   PptyAge
# SalePrice       0.188493      0.331919  -0.009167    0.024597 -0.185668
# NbrLivingUnits  0.142438      0.087586  -0.019790    0.020533  0.098408
# BldgGrade       0.346334      0.616993  -0.171071   -0.011961 -0.472223
# Stories         0.218944      0.506066  -0.270637    0.005820 -0.479102
# SqFtTotLiving   0.598069      0.736130  -0.088891    0.050420 -0.378693
# Bedrooms        1.000000      0.542030   0.004222    0.011663 -0.199428
# BathCountSum    0.542030      1.000000  -0.133285    0.038319 -0.546523
# Condition       0.004222     -0.133285   1.000000   -0.078947  0.383793
# Renovation      0.011663      0.038319  -0.078947    1.000000 -0.175403
# PptyAge        -0.199428     -0.546523   0.383793   -0.175403  1.000000

# %%
#remove NbrLivingUnits and Condition due to low correlation 
#(Condition maybe better modified as categorical variable)
kc_train = kc_train.drop(['NbrLivingUnits', 'Condition'], axis=1)

# %%
sns.heatmap(kc_train.corr())

# %%
#separate features and dependant variable
kc_train_features = kc_train.drop(['SalePrice'], axis=1)
kc_train_price = kc_train['SalePrice']

# %%
x = kc_train_features
y = kc_train_price

# %%
predictors_int = sm.add_constant(x)
model = sm.OLS(y,predictors_int).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.204
# Model:                            OLS   Adj. R-squared:                  0.204
# Method:                 Least Squares   F-statistic:                 2.246e+04
# Date:                Fri, 12 Jul 2019   Prob (F-statistic):               0.00
# Time:                        01:41:53   Log-Likelihood:            -8.3138e+06
# No. Observations:              613428   AIC:                         1.663e+07
# Df Residuals:                  613420   BIC:                         1.663e+07
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -2.623e+05   2598.070   -100.956      0.000   -2.67e+05   -2.57e+05
# BldgGrade      5.499e+04    350.980    156.676      0.000    5.43e+04    5.57e+04
# Stories        3.809e+04    579.709     65.706      0.000     3.7e+04    3.92e+04
# SqFtTotLiving    37.8900      0.563     67.305      0.000      36.787      38.993
# Bedrooms      -8838.2914    349.038    -25.322      0.000   -9522.395   -8154.187
# BathCountSum   1.908e+04    568.016     33.599      0.000     1.8e+04    2.02e+04
# Renovation     3.265e+04   1175.026     27.787      0.000    3.03e+04     3.5e+04
# PptyAge         608.8446     10.934     55.684      0.000     587.414     630.275
# ==============================================================================
# Omnibus:                    49047.626   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            63628.283
# Skew:                           0.712   Prob(JB):                         0.00
# Kurtosis:                       3.679   Cond. No.                     2.43e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.43e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model.mse_model
# Out:
# 777862156295765.1

# %%
model.mse_resid
# Out:
# 34638524894.95666
